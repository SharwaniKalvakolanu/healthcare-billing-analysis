# %%
import pandas as pd
df = pd.read_csv('../data/raw/Medicare_Provider_Util_Payment_PUF_CY2023.csv')
# Out:
# /var/folders/j3/yz8yx0vd45qfg3gz7ggpgxhc0000gn/T/ipykernel_87685/1596799701.py:2: DtypeWarning: Columns (10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw/Medicare_Provider_Util_Payment_PUF_CY2023.csv')

# %%
df.head()
# Out:
#    Rndrng_NPI Rndrng_Prvdr_Last_Org_Name Rndrng_Prvdr_First_Name  \
# 0  1003000126                  Enkeshafi                 Ardalan
# 1  1003000126                  Enkeshafi                 Ardalan
# 2  1003000126                  Enkeshafi                 Ardalan
# 3  1003000126                  Enkeshafi                 Ardalan
# 4  1003000126                  Enkeshafi                 Ardalan
#
#   Rndrng_Prvdr_MI Rndrng_Prvdr_Crdntls Rndrng_Prvdr_Ent_Cd  \
# 0             NaN                 M.D.                   I
# 1             NaN                 M.D.                   I
# 2             NaN                 M.D.                   I
# 3             NaN                 M.D.                   I
# 4             NaN                 M.D.                   I
#
#             Rndrng_Prvdr_St1 Rndrng_Prvdr_St2 Rndrng_Prvdr_City  \
# 0  6410 Rockledge Dr Ste 304              NaN          Bethesda
# 1  6410 Rockledge Dr Ste 304              NaN          Bethesda
# ...

# %%
df.shape
# Out:
# (9660647, 28)

# %%
df.columns
# Out:
# Index(['Rndrng_NPI', 'Rndrng_Prvdr_Last_Org_Name', 'Rndrng_Prvdr_First_Name',
#        'Rndrng_Prvdr_MI', 'Rndrng_Prvdr_Crdntls', 'Rndrng_Prvdr_Ent_Cd',
#        'Rndrng_Prvdr_St1', 'Rndrng_Prvdr_St2', 'Rndrng_Prvdr_City',
#        'Rndrng_Prvdr_State_Abrvtn', 'Rndrng_Prvdr_State_FIPS',
#        'Rndrng_Prvdr_Zip5', 'Rndrng_Prvdr_RUCA', 'Rndrng_Prvdr_RUCA_Desc',
#        'Rndrng_Prvdr_Cntry', 'Rndrng_Prvdr_Type',
#        'Rndrng_Prvdr_Mdcr_Prtcptg_Ind', 'HCPCS_Cd', 'HCPCS_Desc',
#        'HCPCS_Drug_Ind', 'Place_Of_Srvc', 'Tot_Benes', 'Tot_Srvcs',
#        'Tot_Bene_Day_Srvcs', 'Avg_Sbmtd_Chrg', 'Avg_Mdcr_Alowd_Amt',
#        'Avg_Mdcr_Pymt_Amt', 'Avg_Mdcr_Stdzd_Amt'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Rndrng_NPI  Rndrng_Prvdr_RUCA     Tot_Benes     Tot_Srvcs  \
# count  9.660647e+06       9.653047e+06  9.660647e+06  9.660647e+06
# mean   1.499464e+09       1.563976e+00  8.537118e+01  2.738522e+02
# std    2.877096e+08       3.352656e+00  1.354371e+03  6.814589e+03
# min    1.003000e+09       1.000000e+00  1.100000e+01  5.500000e+00
# 25%    1.245948e+09       1.000000e+00  1.700000e+01  2.100000e+01
# 50%    1.497947e+09       1.000000e+00  3.200000e+01  4.300000e+01
# 75%    1.740786e+09       1.000000e+00  7.100000e+01  1.160000e+02
# max    1.993000e+09       9.900000e+01  8.704860e+05  5.208424e+06
#
#        Tot_Bene_Day_Srvcs  Avg_Sbmtd_Chrg  Avg_Mdcr_Alowd_Amt  \
# count        9.660647e+06    9.660647e+06        9.660647e+06
# mean         1.364925e+02    4.168288e+02        1.061070e+02
# std          2.185786e+03    1.433275e+03        3.223192e+02
# min          1.100000e+01    5.000000e-05        0.000000e+00
# ...

# %%
# Just show 3 columns to start
df[['Rndrng_Prvdr_Type', 'Avg_Sbmtd_Chrg', 'Avg_Mdcr_Pymt_Amt']].head(10)
# Out:
#   Rndrng_Prvdr_Type  Avg_Sbmtd_Chrg  Avg_Mdcr_Pymt_Amt
# 0       Hospitalist      250.226667          60.312500
# 1       Hospitalist      318.581818          99.380000
# 2       Hospitalist       95.732283          43.557323
# 3       Hospitalist      194.441525          69.086422
# 4       Hospitalist      251.454051         100.943165
# 5       Hospitalist      181.606154          68.387692
# 6       Hospitalist      278.034154          99.888359
# 7         Pathology      115.000000           8.873437
# 8         Pathology      170.000000          27.654756
# 9         Pathology       88.000000          20.885919

# %%
df.columns
# Out:
# Index(['Rndrng_NPI', 'Rndrng_Prvdr_Last_Org_Name', 'Rndrng_Prvdr_First_Name',
#        'Rndrng_Prvdr_MI', 'Rndrng_Prvdr_Crdntls', 'Rndrng_Prvdr_Ent_Cd',
#        'Rndrng_Prvdr_St1', 'Rndrng_Prvdr_St2', 'Rndrng_Prvdr_City',
#        'Rndrng_Prvdr_State_Abrvtn', 'Rndrng_Prvdr_State_FIPS',
#        'Rndrng_Prvdr_Zip5', 'Rndrng_Prvdr_RUCA', 'Rndrng_Prvdr_RUCA_Desc',
#        'Rndrng_Prvdr_Cntry', 'Rndrng_Prvdr_Type',
#        'Rndrng_Prvdr_Mdcr_Prtcptg_Ind', 'HCPCS_Cd', 'HCPCS_Desc',
#        'HCPCS_Drug_Ind', 'Place_Of_Srvc', 'Tot_Benes', 'Tot_Srvcs',
#        'Tot_Bene_Day_Srvcs', 'Avg_Sbmtd_Chrg', 'Avg_Mdcr_Alowd_Amt',
#        'Avg_Mdcr_Pymt_Amt', 'Avg_Mdcr_Stdzd_Amt', 'charge_to_payment_ratio'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()  # remove leading/trailing spaces

# %%
df['charge_to_payment_ratio'] = df['Avg_Sbmtd_Chrg'] / (df['Avg_Mdcr_Pymt_Amt'] + 1)

# %%
df[['Rndrng_Prvdr_Type', 'Avg_Sbmtd_Chrg', 'Avg_Mdcr_Pymt_Amt', 'charge_to_payment_ratio']].head(10)
# Out:
#   Rndrng_Prvdr_Type  Avg_Sbmtd_Chrg  Avg_Mdcr_Pymt_Amt  \
# 0       Hospitalist      250.226667          60.312500
# 1       Hospitalist      318.581818          99.380000
# 2       Hospitalist       95.732283          43.557323
# 3       Hospitalist      194.441525          69.086422
# 4       Hospitalist      251.454051         100.943165
# 5       Hospitalist      181.606154          68.387692
# 6       Hospitalist      278.034154          99.888359
# 7         Pathology      115.000000           8.873437
# 8         Pathology      170.000000          27.654756
# 9         Pathology       88.000000          20.885919
#
#    charge_to_payment_ratio
# 0                 4.081169
# 1                 3.173758
# 2                 2.148520
# 3                 2.774311
# 4                 2.466610
# 5                 2.617268
# 6                 2.755860
# 7                11.647413
# 8                 5.932698
# 9                 4.020850

# %%
df[['Rndrng_Prvdr_State_FIPS', 'Rndrng_Prvdr_Zip5', 'Rndrng_Prvdr_RUCA', 'Rndrng_Prvdr_RUCA_Desc', 'Rndrng_Prvdr_Cntry', 'Rndrng_Prvdr_Type', 'Rndrng_Prvdr_Mdcr_Prtcptg_Ind', 'HCPCS_Cd']]
# Out:
#         Rndrng_Prvdr_State_FIPS Rndrng_Prvdr_Zip5  Rndrng_Prvdr_RUCA  \
# 0                            24             20817                1.0
# 1                            24             20817                1.0
# 2                            24             20817                1.0
# 3                            24             20817                1.0
# 4                            24             20817                1.0
# ...                         ...               ...                ...
# 9660642                      53             98101                1.0
# 9660643                      51             23227                1.0
# 9660644                      51             23227                1.0
# 9660645                      51             23227                1.0
# 9660646                      51             23227                1.0
#
#                                     Rndrng_Prvdr_RUCA_Desc Rndrng_Prvdr_Cntry  \
# ...
